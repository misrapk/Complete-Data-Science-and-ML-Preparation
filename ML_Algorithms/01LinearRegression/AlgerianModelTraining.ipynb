# %%
#import basic libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#load clean dataset
df = pd.read_csv('Algerian_Forest_firesdataset_Cleaned.csv')
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
#drop month day and year
df.drop(['day', 'month', 'year'], axis=1, inplace=True)
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
#modify the other 'not fire' and use only fire and 'not fire'
df['Classes'] = np.where(df['Classes'].str.contains('not fire'),0,1)
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
#independent features and dependent features
X= df.drop('FWI', axis=1)   
y = df['FWI']

X,y
# Out:
# (     Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  Classes  Region
#  0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4        0       0
#  1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9        0       0
#  2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7        0       0
#  3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7        0       0
#  4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9        0       0
#  ..           ...  ..  ..   ...   ...   ...   ...  ...   ...      ...     ...
#  238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9        1       1
#  239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2        0       1
#  240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4        0       1
#  241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1        0       1
#  242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8        0       1
#
#  [243 rows x 11 columns],
#  0      0.5
#  1      0.4
#  2      0.1
#  3      0.0
#  4      0.5
#        ...
#  238    6.5
#  239    0.0
#  240    0.2
#  241    0.7
#  242    0.5
#  Name: FWI, Length: 243, dtype: float64)

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

print("X_train shape: ", X_train.shape)
print("X_test shape: ", X_test.shape)
print("y_train shape: ", y_train.shape)
print("y_test shape: ", y_test.shape)
# Out:
# X_train shape:  (170, 11)
# X_test shape:  (73, 11)
# y_train shape:  (170,)
# y_test shape:  (73,)

# %% [markdown]
# ## 1.  Feature selection based on Correlation
#
#
# Remove - highly positively correlated
# Important = highly negatively correlated

# %% [markdown]
# #### 1.1 Check for multicolinearity

# %%
#plot correlation of X_train
plt.figure(figsize=(12,10))
sns.heatmap(X_train.corr(), annot=True)
# Out:
# <Axes: >

# %%
#function to remove highly positively correlated features
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
## threshold -- Domain expertise... here we are giving 85% correlation
corr_featuers = correlation(X_train, 0.85) #greater than 85%

corr_featuers
# Out:
# {'BUI', 'DC'}

# %%
## drop the highly correlated features (more than 85%)
X_train.drop(corr_featuers, axis=1, inplace=True)
X_test.drop(corr_featuers, axis=1, inplace=True)

X_train.shape, X_test.shape
# Out:
# ((170, 9), (73, 9))

# %% [markdown]
# #### 1.2 Feature Scaling or Standardisation

# %%
#standardisation
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


X_train_scaled, X_test_scaled
# Out:
# (array([[ 0.80614849,  0.28425439, -0.13063868, ..., -0.33001657,
#           0.88852332,  0.976741  ],
#         [ 1.08640461, -0.80166126,  0.23950424, ...,  1.17707817,
#           0.88852332,  0.976741  ],
#         [-0.03461987, -0.46231262, -0.5007816 , ...,  0.08321908,
#           0.88852332,  0.976741  ],
#         ...,
#         [ 1.08640461, -0.25870343,  1.34993301, ...,  1.10415423,
#           0.88852332, -1.02381286],
#         [-1.7161566 ,  1.30230032,  1.34993301, ...,  0.03460312,
#           0.88852332, -1.02381286],
#         [-0.87538824,  0.75934249,  0.60964717, ..., -0.79186819,
#          -1.12546287, -1.02381286]], shape=(170, 9)),
#  array([[ 1.36666074, -1.75183746, -0.87092453, -0.09099764,  0.60264375,
#           0.31658007,  0.03460312,  0.88852332,  0.976741  ],
#         [-2.27666885,  0.14851493, -0.13063868, -0.295893  , -0.74857353,
#          -0.90538841, -0.84048414, -1.12546287,  0.976741  ],
#         [-1.43590048,  1.0308214 ,  0.23950424, -0.39834068, -0.92730597,
#          -0.97471996, -0.84048414, -1.12546287, -1.02381286],
#         [-0.314876  , -0.46231262, -1.61121037, -0.39834068,  0.71703251,
#           0.19524987,  0.180451  ,  0.88852332, -1.02381286],
#         [ 0.24563625,  0.08064521,  0.60964717,  0.16512155, -0.35536215,
#           0.57657337, -0.74325223, -1.12546287,  0.976741  ],
#         [-2.83718109,  1.64164896, -0.13063868,  4.77526709, -3.3795151 ,
#          -1.17404815, -1.1321799 , -1.12546287, -1.02381286],
#         [-0.314876  ,  0.89508195, -0.87092453, -0.34711684, -0.1909283 ,
#          -0.55006425, -0.76756021, -1.12546287, -1.02381286],
#         [-0.03461987,  0.01277548,  0.97979009, -0.34711684,  0.25947745,
#          -0.52406492, -0.33001657,  0.88852332, -1.02381286],
#         [ 0.52589237,  1.30230032, -0.13063868, -0.39834068,  0.28807464,
#          -0.39406827, -0.40294051, -1.12546287, -1.02381286],
#         [-1.43590048,  1.70951869,  5.05136225, -0.14222148, -2.27852325,
#          -0.93138774, -1.03494798, -1.12546287,  0.976741  ],
#         [ 0.80614849,  0.41999385,  0.23950424, -0.39834068,  0.53830007,
#          -0.36806894,  0.0589111 ,  0.88852332,  0.976741  ],
#         [ 0.24563625, -0.19083371,  0.23950424,  0.01145003, -0.25527198,
#          -0.62806223, -0.74325223, -1.12546287,  0.976741  ],
#         [ 0.80614849, -0.19083371,  0.60964717, -0.39834068,  0.68843532,
#           0.04792033,  0.5450707 ,  0.88852332, -1.02381286],
#         [-0.87538824,  1.84525814, -0.87092453, -0.0397738 , -2.97915442,
#          -1.08738372, -1.1321799 , -1.12546287, -1.02381286],
#         [-0.87538824,  0.89508195,  0.23950424, -0.39834068,  0.21658167,
#          -0.94005419, -0.45155647,  0.88852332, -1.02381286],
#         [ 0.52589237, -1.48035854,  0.97979009, -0.39834068,  1.02445231,
#           3.64449424,  2.34386119,  0.88852332,  0.976741  ],
#         [ 0.24563625,  0.5557333 ,  0.60964717, -0.39834068,  0.54544936,
#           0.36857873,  0.13183504,  0.88852332, -1.02381286],
#         [ 1.64691686, -1.27674936, -0.87092453, -0.14222148,  0.51685217,
#          -0.10807564, -0.13555273,  0.88852332,  0.976741  ],
#         [-1.7161566 ,  1.37017004,  2.46036178,  6.31198227, -2.19273167,
#          -1.01805218, -1.05925596, -1.12546287, -1.02381286],
#         [ 0.52589237, -0.86953099, -0.13063868, -0.39834068,  0.81712268,
#           0.91456465,  0.83676645,  0.88852332,  0.976741  ],
#         [ 0.52589237,  0.21638466, -0.87092453, -0.39834068,  0.64553953,
#          -0.27273806,  0.13183504,  0.88852332, -1.02381286],
#         [ 0.80614849,  0.41999385,  1.34993301, -0.39834068,  0.752779  ,
#           1.00989552,  1.00692231,  0.88852332, -1.02381286],
#         [-0.314876  ,  0.21638466,  0.97979009, -0.39834068,  0.46680709,
#          -0.15140786,  0.03460312,  0.88852332, -1.02381286],
#         [-0.03461987,  0.89508195, -0.5007816 , -0.39834068,  0.61694234,
#          -0.10807564,  0.13183504,  0.88852332, -1.02381286],
#         [-0.03461987, -0.93740072,  0.97979009, -0.39834068,  0.98155653,
#           2.59585462,  2.07647342,  0.88852332,  0.976741  ],
#         [-1.43590048, -0.25870343,  0.60964717, -0.39834068,  0.79567478,
#           0.61123914,  0.98261433,  0.88852332,  0.976741  ],
#         [ 0.24563625,  0.96295167, -0.13063868, -0.39834068,  0.62409164,
#           0.87989888,  0.22906696,  0.88852332, -1.02381286]]))

# %% [markdown]
# #### box plot to understand effect of standard scaler

# %%
#plotbox plot
plt.figure(figsize=(12,10))
plt.subplot(1,2,1)
sns.boxplot(data=X_train)
plt.xticks(rotation = 90)
plt.title ('Before scaling')

plt.subplot(1,2,2)
sns.boxplot(data=X_train_scaled)
plt.xticks(rotation = 90)
plt.title ('After scaling')
# Out:
# Text(0.5, 1.0, 'After scaling')

# %% [markdown]
# # 2. Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

linreg = LinearRegression()

# %%
linreg.fit(X_train_scaled, y_train)
y_pred = linreg.predict(X_test_scaled)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error: ", mae)
print("Mean Squared Error: ", mse)
print("Root Mean Squared Error: ", rmse)
print("R2 Score: ", r2)
# Out:
# Mean Absolute Error:  0.7375782113730383
# Mean Squared Error:  1.0704237020026868
# Root Mean Squared Error:  1.0346128271013688
# R2 Score:  0.9839691127937101

# %%
#scatter the plot
plt.scatter(y_test, y_pred)

# %% [markdown]
# # 3. Lasso Regerssion Model

# %%
#lasso
from sklearn.linear_model import Lasso
lassoReg = Lasso()
lassoReg.fit(X_train_scaled, y_train)
y_pred = lassoReg.predict(X_test_scaled)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error: ", mae)
print("Mean Squared Error: ", mse)
print("Root Mean Squared Error: ", rmse)
print("R2 Score: ", r2)


plt.scatter(y_test, y_pred)
# Out:
# Mean Absolute Error:  1.4315355794906446
# Mean Squared Error:  3.8300013934332604
# Root Mean Squared Error:  1.957038935083628
# R2 Score:  0.9426411053649225

# %% [markdown]
# ### 3.1 Cross Validation Lasso

# %%
#CV Lasso
from sklearn.linear_model import LassoCV
lassoCV = LassoCV(cv =5)
lassoCV.fit(X_train_scaled, y_train)
# Out:
# LassoCV(cv=5)

# %%
#to see the alpha
lassoCV.alpha_
# Out:
# np.float64(0.026093908403925278)

# %%
#what all the alphas that it tried
(lassoCV.alphas_)
# Out:
# array([6.46366035, 6.02803128, 5.62176215, 5.24287419, 4.88952202,
#        4.5599846 , 4.2526569 , 3.96604206, 3.6987441 , 3.44946112,
#        3.21697899, 3.00016537, 2.79796427, 2.60939084, 2.43352663,
#        2.26951508, 2.11655736, 1.97390848, 1.84087365, 1.71680493,
#        1.60109802, 1.49318938, 1.39255341, 1.29869997, 1.21117194,
#        1.129543  , 1.05341559, 0.9824189 , 0.91620716, 0.85445786,
#        0.79687026, 0.74316387, 0.69307711, 0.64636604, 0.60280313,
#        0.56217621, 0.52428742, 0.4889522 , 0.45599846, 0.42526569,
#        0.39660421, 0.36987441, 0.34494611, 0.3216979 , 0.30001654,
#        0.27979643, 0.26093908, 0.24335266, 0.22695151, 0.21165574,
#        0.19739085, 0.18408737, 0.17168049, 0.1601098 , 0.14931894,
#        0.13925534, 0.12987   , 0.12111719, 0.1129543 , 0.10534156,
#        0.09824189, 0.09162072, 0.08544579, 0.07968703, 0.07431639,
#        0.06930771, 0.0646366 , 0.06028031, 0.05621762, 0.05242874,
#        0.04889522, 0.04559985, 0.04252657, 0.03966042, 0.03698744,
#        0.03449461, 0.03216979, 0.03000165, 0.02797964, 0.02609391,
#        0.02433527, 0.02269515, 0.02116557, 0.01973908, 0.01840874,
#        0.01716805, 0.01601098, 0.01493189, 0.01392553, 0.012987  ,
#        0.01211172, 0.01129543, 0.01053416, 0.00982419, 0.00916207,
#        0.00854458, 0.0079687 , 0.00743164, 0.00693077, 0.00646366])

# %%
y_pred = lassoCV.predict(X_test_scaled)
plt.scatter(y_test, y_pred)

# %% [markdown]
# # 4. Ridge Regression

# %%
from sklearn.linear_model import Ridge
ridgeReg = Ridge()
ridgeReg.fit(X_train_scaled, y_train)
y_pred = ridgeReg.predict(X_test_scaled)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
 
print("Mean Absolute Error: ", mae)
print("Mean Squared Error: ", mse)
print("Root Mean Squared Error: ", rmse)
print("R2 Score: ", r2)

plt.scatter(y_test, y_pred)
# Out:
# Mean Absolute Error:  0.7639446488846958
# Mean Squared Error:  1.1168940846733044
# Root Mean Squared Error:  1.0568320986198823
# R2 Score:  0.9832731627118574

# %% [markdown]
# ### 4.1 Ridge Regression CV

# %%
#RIDGE CV
from sklearn.linear_model import RidgeCV
ridgeCV = RidgeCV(cv=2)
ridgeCV.fit(X_train_scaled, y_train)
# Out:
# RidgeCV(cv=2)

# %%
ridgeCV.alphas
# Out:
# (0.1, 1.0, 10.0)

# %%
ridgeCV.alpha_
# Out:
# np.float64(1.0)

# %%
y_pred=ridgeCV.predict(X_test_scaled)
plt.scatter(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2Score = r2_score(y_test, y_pred)
print("Mean Absolute Error: ", mae)
print("Mean Squared Error: ", mse)
print("R 2 Score : ", r2Score)
# Out:
# Mean Absolute Error:  0.7639446488846958
# Mean Squared Error:  1.1168940846733044
# R 2 Score :  0.9832731627118574
