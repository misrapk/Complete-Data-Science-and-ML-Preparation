# %%
from sklearn.datasets import fetch_openml

mnist = fetch_openml('mnist_784', as_frame=False)

# %%
X = mnist.data
y = mnist.target

# %%
X.shape
# Out:
# (70000, 784)

# %%
y.shape
# Out:
# (70000,)

# %% [markdown]
# 1. 70000 images and each image has 784 features
# 2. Each image is 28x28 pixels

# %%
# display one image
import matplotlib.pyplot as plt

image = X[0].reshape(28,28)
plt.imshow(image, cmap='binary')
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(27.5), np.float64(27.5), np.float64(-0.5))

# %%
def printDigit(digitImage):
    """ to display image as plot"""
    image = digitImage.reshape(28,28)
    plt.imshow(image, cmap='binary')
    plt.axis("off")

# %%
print(y[200])
printDigit(X[200])
# Out:
# 1

# %% [markdown]
# Before doing anything. split the data in train and test set
#
# train = 60000 images
# test = 10000 images

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test= train_test_split(X, y, train_size=0.85, random_state=42)

# %%
X_train.shape
# Out:
# (59500, 784)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Training a Binary Classifier

# %% [markdown]
# ##### First make 5 detector to detect 5

# %%
# Create Target Vector for this classification task
y_train_5 = y_train=='5'
y_test_5 = y_test == '5'

# %%
from sklearn.linear_model import SGDClassifier

sgdClf = SGDClassifier(random_state=42)
sgdClf.fit(X_train, y_train_5)
# Out:
# SGDClassifier(random_state=42)

# %%
sgdClf.predict(X[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sgdClf.predict(X[0])
#
# File e:\CODING\Data Science\DataScience ML Scratch2025\DS from Scratch\myenv\Lib\site-packages\sklearn\linear_model\_base.py:374, in LinearClassifierMixin.predict(self, X)
#     360 """
#     361 Predict class labels for samples in X.
#     362
#    (...)
#     371     Vector containing the class labels for each sample.
#     372 """
#     373 xp, _ = get_namespace(X)
# --> 374 scores = self.decision_function(X)
#     375 if len(scores.shape) == 1:
#     376     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# File e:\CODING\Data Science\DataScience ML Scratch2025\DS from Scratch\myenv\Lib\site-packages\sklearn\linear_model\_base.py:351, in LinearClassifierMixin.decision_function(self, X)
#     348 check_is_fitted(self)
#     349 xp, _ = get_namespace(X)
# ...
